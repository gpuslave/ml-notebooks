# %%
# %pip install tqdm
import pandas as pd
import numpy as np
from tqdm import trange
# Out:
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ------------- ------------------------ 20.5/57.6 kB 640.0 kB/s eta 0:00:01
#      --------------------------------- ---- 51.2/57.6 kB 525.1 kB/s eta 0:00:01
#      -------------------------------------- 57.6/57.6 kB 503.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ------------------------------- -------- 61.4/78.3 kB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 78.3/78.3 kB 1.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
a = pd.read_csv('data_sets/melb_data.csv')
print(a.iloc[:10, :3])

# for i in (t := trange(200)):
#     t.set_description('Processing %i' % i)
# Out:
# Processing 199: 100%|██████████| 200/200 [00:00<00:00, 2617.23it/s]
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# aboba
# ...
